# %%
import mglearn
import numpy as np
import pandas as pd

# %%
mglearn.plots.plot_knn_regression(n_neighbors=1)

# %%
mglearn.plots.plot_knn_regression(n_neighbors=3)

# %%
X,y=mglearn.datasets.make_wave(n_samples=40)

# %%
# %matplotlib notebook
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
import matplotlib.pyplot as plt
import numpy as np
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=10)

reg=KNeighborsRegressor(n_neighbors=3)
reg.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
print('Test predictions: ',reg.predict(X_test))
# Out:
# Test predictions:  [ 4.83634922e-01  1.06672296e-03  4.83634922e-01  4.17694837e-01
#  -1.14241878e+00 -1.14241878e+00  9.45087517e-01 -3.24834693e-01
#  -1.58822285e+00  9.45087517e-01]

# %%
reg.score(X_test,y_test)
# Out:
# 0.7694613423685766

# %%
fig,axes=plt.subplots(1,3,figsize=(15,4))
line=np.linspace(-3,3,1000).reshape(-1,1)

for n_neighbors,ax in zip([1,3,9],axes):
    reg=KNeighborsRegressor(n_neighbors=n_neighbors)
    reg.fit(X_train,y_train)
    ax.plot(line,reg.predict(line))
    ax.plot(X_train,y_train,'^',c=mglearn.cm2(0),markersize=8)
    ax.plot(X_test,y_test,'v',c=mglearn.cm2(1),markersize=8)
    
    ax.set_title(
        "{}neighbors\n train score: {:.2f} test score:{:.2f}".format(
            n_neighbors,reg.score(X_train,y_train),reg.score(X_test,y_test)))
    ax.set_xlabel("feature")
    ax.set_ylabel("Target")
axes[0].legend(["Model predictions","Training data/target","Test data/target"],loc="best")
# Out:
# <img src="data:image/png;base64,..." width="1499.6666666666667">

# %% [markdown]
# Strengths:
#     1.It is very easy to understand and gives reasonable performance without a lot of adjustments.
#     2.Using this algorithm is a good baseline method to to try before considering more advanced techniques.
#
# Weaknesses:
#     1. With large datasets predictions can be slow.
#     2.Does not perform well on sparse dataset.
#
# In short K-nearest neighbours are easy to understand, it not often used in practise,
# due to prediction being slow and inability to handle many features.
